# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Assignment: Sorting and Aggregating Data 📍 📍</h1></center>
#
# ---
#
# #### `READ THE DATASET`
#
# ---

# %%
import pandas as pd

# %%
data = pd.read_csv('time_series.csv')

# %%
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %% [markdown]
# #### `Convert the Datetime column to pandas datetime object`
#
# ---

# %%
# WRITE YOUR CODE HERE

# %%
# Convert the Datetime column to datetime
data['Datetime'] = pd.to_datetime(data['Datetime'])
# Out:
# <ipython-input-4-0e3f8aaf69fd>:2: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Datetime'] = pd.to_datetime(data['Datetime'])

# %%
data.dtypes
# Out:
# ID                   int64
# Datetime    datetime64[ns]
# Count                int64
# dtype: object

# %% [markdown]
# ---
#
# ####  `Create the following features using the Datetime feature`
#
# - day of month
# - month
# - day of year
# - hour
#
# ---

# %%
# WRITE YOUR CODE HERE

# %%
# Create day of month feature
data['day_of_month'] = data['Datetime'].dt.day

# Create month feature
data['month'] = data['Datetime'].dt.month

# Create day of year feature
data['day_of_year'] = data['Datetime'].dt.dayofyear

# Create hour feature
data['hour'] = data['Datetime'].dt.hour

# %%
data
# Out:
#           ID            Datetime  Count  day_of_month  month  day_of_year  \
# 0          0 2012-08-25 00:00:00      8            25      8          238
# 1          1 2012-08-25 01:00:00      2            25      8          238
# 2          2 2012-08-25 02:00:00      6            25      8          238
# 3          3 2012-08-25 03:00:00      2            25      8          238
# 4          4 2012-08-25 04:00:00      2            25      8          238
# ...      ...                 ...    ...           ...    ...          ...
# 18283  18283 2014-09-25 19:00:00    868            25      9          268
# 18284  18284 2014-09-25 20:00:00    732            25      9          268
# 18285  18285 2014-09-25 21:00:00    702            25      9          268
# 18286  18286 2014-09-25 22:00:00    580            25      9          268
# 18287  18287 2014-09-25 23:00:00    534            25      9          268
#
#        hour
# 0         0
# 1         1
# 2         2
# 3         3
# ...

# %% [markdown]
# ---
#
# #### `Consider the following dataframe`
#
# ---

# %%
sample_df = pd.DataFrame({
    'id'   :  [1, 2, 3, 4, 5],
    'name' :  [ 'Akash', 'Akansha', 'Naman', 'Pulkit', 'Anand'],
    'marks':  [ 22, 23, 43, 41, 12]
})
sample_df
# Out:
#    id     name  marks
# 0   1    Akash     22
# 1   2  Akansha     23
# 2   3    Naman     43
# 3   4   Pulkit     41
# 4   5    Anand     12

# %% [markdown]
# #### Sort the  dataframe by `marks` column in descending order
#
# ---

# %%
# WRITE YOUR CODE HERE

# %%
# Sort by marks in descending order
sorted_df = sample_df.sort_values(by='marks', ascending=False)

# Display the sorted DataFrame
sorted_df
# Out:
#    id     name  marks
# 2   3    Naman     43
# 3   4   Pulkit     41
# 1   2  Akansha     23
# 0   1    Akash     22
# 4   5    Anand     12

# %% [markdown]
# #### Consider another dataframe city
# ---

# %%
city = pd.DataFrame({
    'name' : ['Akash', 'Akansha', 'Pulkit', 'Anand', 'Naman'],
    'city' : ['Delhi', 'Gurugram', 'Gurugram', 'Delhi', 'Noida']
})
city
# Out:
#       name      city
# 0    Akash     Delhi
# 1  Akansha  Gurugram
# 2   Pulkit  Gurugram
# 3    Anand     Delhi
# 4    Naman     Noida

# %% [markdown]
# ***Use the dataframe `sample_df` and `city` and find out the marks of students who live in Gurugram.***
#
# ---

# %%
### Write your code here

# %%
# Merge the two DataFrames on the 'name' column
merged_df = pd.merge(sample_df, city, on='name')

# Filter for students who live in Gurugram
gurugram_students = merged_df[merged_df['city'] == 'Gurugram']

# Select the relevant columns
result = gurugram_students[['name', 'marks', 'city']]

# Display the result
result
# Out:
#       name  marks      city
# 1  Akansha     23  Gurugram
# 3   Pulkit     41  Gurugram

# %% [markdown]
# #### `READ THE BIG MART SALES DATA`
#
# ---

# %%
big_mart_data = pd.read_csv('big_mart_sales.csv')

# %%
big_mart_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### Find out the number of unique `Item_Type` in each of the `Outlet_Identifier`
#
# ---

# %%
# WRITE YOUR CODE HERE

# %%
# Count unique Item_Types for each Outlet_Identifier
outlet_item_types = big_mart_data.groupby('Outlet_Identifier')['Item_Type'].nunique()

# Display the results
outlet_item_types
# Out:
# Outlet_Identifier
# OUT010    16
# OUT013    16
# OUT017    16
# OUT018    16
# OUT019    16
# OUT027    16
# OUT035    16
# OUT045    16
# OUT046    16
# OUT049    16
# Name: Item_Type, dtype: int64

# %% [markdown]
# #### Find out the average `Item_Outlet_Sales` for each category of `Outlet_Size`
#
# ---

# %%
# WRITE YOUR CODE HERE

# %%
# Calculate average Item_Outlet_Sales for each Outlet_Size category
avg_sales_by_size = big_mart_data.groupby('Outlet_Size')['Item_Outlet_Sales'].mean()

# Display the results
avg_sales_by_size
# Out:
# Outlet_Size
# High      2298.995256
# Medium    2681.603542
# Small     1912.149161
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# #### Select only the categorical variables from the dataframe and use `get_dummies` function to convert those into the numerical ones.
#
# ---

# %%
# WRITE YOUR CODE HERE

# %%
# Step 1: Select only categorical columns
# Assuming categorical columns are those with 'object' or 'category' dtype
categorical_cols = big_mart_data.select_dtypes(include=['object', 'category']).columns

# Step 2: Create a dataframe with only categorical columns
categorical_data = big_mart_data[categorical_cols]

# Step 3: Convert categorical variables to dummy/indicator variables
dummy_data = pd.get_dummies(categorical_data, drop_first=True)

# %%
dummy_data
# Out:
#       Item_Identifier_DRA24  Item_Identifier_DRA59  Item_Identifier_DRB01  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 8518                  False                  False                  False
# 8519                  False                  False                  False
# 8520                  False                  False                  False
# 8521                  False                  False                  False
# 8522                  False                  False                  False
#
#       Item_Identifier_DRB13  Item_Identifier_DRB24  Item_Identifier_DRB25  \
# ...

# %%
# Step 4: If you want to join these back to the original numerical columns
numerical_cols = big_mart_data.select_dtypes(exclude=['object', 'category']).columns
numerical_data = big_mart_data[numerical_cols]

# Step 5: Combine numerical and one-hot encoded data
final_data = pd.concat([numerical_data, dummy_data], axis=1)

# Display the first few rows of the transformed data
final_data.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#    Item_Outlet_Sales  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0          3735.1380                  False                  False
# 1           443.4228                  False                  False
# 2          2097.2700                  False                  False
# 3           732.3800                  False                  False
# 4           994.7052                  False                  False
#
#    Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  ...  \
# ...
